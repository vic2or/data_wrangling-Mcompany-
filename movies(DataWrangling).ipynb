# %%
import pandas as pd

# %%
import numpy as np

# %%
pd.read_csv('assignment.csv')
# Out:
#     IMBD title ID               Original titlÊ  Release year  \
# 0       tt0111161     The Shawshank Redemption    1995-02-10
# 1       tt0068646                The Godfather    09 21 1972
# 2       tt0468569              The Dark Knight   23 -07-2008
# 3       tt0071562       The Godfather: Part II    1975-09-25
# 4       tt0110912                 Pulp Fiction    1994-10-28
# ..            ...                          ...           ...
# 96      tt0070735                    The Sting    1974-03-21
# 97      tt0082096                     Das Boot    1982-03-18
# 98      tt0059578  Per qualche dollaro in piÃ¹    1965-12-20
# 99      tt1832382      Jodaeiye Nader az Simin    2011-10-21
# 100     tt0045152          Singin' in the Rain    1953-02-05
#
#                          Genrë¨ Duration       Country Content Rating  \
# 0                         Drama      142           USA              R
# 1                  Crime, Drama      175           USA              R
# ...

# %%
df=pd.read_csv('assignment.csv')

# %%
df.rename(columns={'Original titlÊ':'original_title','Release year':'release_year','Genrë¨':'genre','':'',' Votes ':'votes','Content Rating':'contemt_rating'}, inplace=True)

# %%
df
# Out:
#     IMBD title ID               original_title  release_year  \
# 0       tt0111161     The Shawshank Redemption    1995-02-10
# 1       tt0068646                The Godfather    09 21 1972
# 2       tt0468569              The Dark Knight   23 -07-2008
# 3       tt0071562       The Godfather: Part II    1975-09-25
# 4       tt0110912                 Pulp Fiction    1994-10-28
# ..            ...                          ...           ...
# 96      tt0070735                    The Sting    1974-03-21
# 97      tt0082096                     Das Boot    1982-03-18
# 98      tt0059578  Per qualche dollaro in piÃ¹    1965-12-20
# 99      tt1832382      Jodaeiye Nader az Simin    2011-10-21
# 100     tt0045152          Singin' in the Rain    1953-02-05
#
#                           genre Duration       Country contemt_rating  \
# 0                         Drama      142           USA              R
# 1                  Crime, Drama      175           USA              R
# ...

# %%
df
# Out:
#     IMBD title ID               original_title  release_year  \
# 0       tt0111161     The Shawshank Redemption    1995-02-10
# 1       tt0068646                The Godfather    09 21 1972
# 2       tt0468569              The Dark Knight   23 -07-2008
# 3       tt0071562       The Godfather: Part II    1975-09-25
# 4       tt0110912                 Pulp Fiction    1994-10-28
# ..            ...                          ...           ...
# 96      tt0070735                    The Sting    1974-03-21
# 97      tt0082096                     Das Boot    1982-03-18
# 98      tt0059578  Per qualche dollaro in piÃ¹    1965-12-20
# 99      tt1832382      Jodaeiye Nader az Simin    2011-10-21
# 100     tt0045152          Singin' in the Rain    1953-02-05
#
#                           genre Duration       Country contemt_rating  \
# 0                         Drama      142           USA              R
# 1                  Crime, Drama      175           USA              R
# ...

# %%
df

# %%
df.columns=df.columns.str.lower()

# %%
df
# Out:
#     imbd title id               original_title  release_year  \
# 0       tt0111161     The Shawshank Redemption    1995-02-10
# 1       tt0068646                The Godfather    09 21 1972
# 2       tt0468569              The Dark Knight   23 -07-2008
# 3       tt0071562       The Godfather: Part II    1975-09-25
# 4       tt0110912                 Pulp Fiction    1994-10-28
# ..            ...                          ...           ...
# 96      tt0070735                    The Sting    1974-03-21
# 97      tt0082096                     Das Boot    1982-03-18
# 98      tt0059578  Per qualche dollaro in piÃ¹    1965-12-20
# 99      tt1832382      Jodaeiye Nader az Simin    2011-10-21
# 100     tt0045152          Singin' in the Rain    1953-02-05
#
#                           genre duration       country contemt_rating  \
# 0                         Drama      142           USA              R
# 1                  Crime, Drama      175           USA              R
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 101 entries, 0 to 100
# Data columns (total 12 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   imbd title id   100 non-null    object
#  1   original_title  100 non-null    object
#  2   release_year    100 non-null    object
#  3   genre           100 non-null    object
#  4   duration        99 non-null     object
#  5   country         100 non-null    object
#  6   contemt_rating  77 non-null     object
#  7   director        100 non-null    object
#  8   unnamed: 8      0 non-null      float64
#  9   income          100 non-null    object
#  10  votes           100 non-null    object
#  11  score           100 non-null    object
# dtypes: float64(1), object(11)
# memory usage: 9.6+ KB

# %%
df.drop(index=13, inplace=True)

# %%
pd.reset_option('display.max_rows', None)

# %%
df
# Out:
#                   original_title release_year      genre  duration  \
# 0       The Shawshank Redemption   1995-02-10      Drama       142
# 1                  The Godfather   1972-09-21      Crime       175
# 2                The Dark Knight   2008-07-23     Action       152
# 3         The Godfather: Part II   1975-09-25      Crime       220
# 4                   Pulp Fiction   1994-10-28      Crime       154
# ..                           ...          ...        ...       ...
# 96                     The Sting   1974-03-21     Comedy       129
# 97                      Das Boot   1982-03-18  Adventure       149
# 98   Per qualche dollaro in piÃ¹   1965-12-20    Western       132
# 99       Jodaeiye Nader az Simin   2011-10-21      Drama       123
# 100          Singin' in the Rain   1953-02-05     Comedy       103
#
#           country              director      income    votes  score
# 0             USA        Frank Darabont    28815245  2278845    9.3
# ...

# %%
##from dateutil.parser import parse    ##I chose not to use this function, I used a 'to_datetime' to achieve same result.

# %%
##def date_parse(date_str):
  ##  try:
 ##       date_log=parse(date_str, dayfirst=True)
 #      return date_log.strftime('%Y-%m-%d')
 #   except(ValueError, TypeError):
  #      return None

# %%
##df['release_year']=df['release_year'].apply(date_parse)

# %%
df
# Out:
#                   original_title release_year      genre  duration  \
# 0       The Shawshank Redemption   1995-02-10      Drama       142
# 1                  The Godfather   1972-09-21      Crime       175
# 2                The Dark Knight   2008-07-23     Action       152
# 3         The Godfather: Part II   1975-09-25      Crime       220
# 4                   Pulp Fiction   1994-10-28      Crime       154
# ..                           ...          ...        ...       ...
# 96                     The Sting   1974-03-21     Comedy       129
# 97                      Das Boot   1982-03-18  Adventure       149
# 98   Per qualche dollaro in piÃ¹   1965-12-20    Western       132
# 99       Jodaeiye Nader az Simin   2011-10-21      Drama       123
# 100          Singin' in the Rain   1953-02-05     Comedy       103
#
#           country              director      income    votes  score
# 0             USA        Frank Darabont    28815245  2278845    9.3
# ...

# %%
df.release_year=pd.to_datetime(df['release_year'], format='mixed', dayfirst=True, errors='coerce')

# %%
df['release_year'].info
# Out:
# <bound method Series.info of 0     1995-02-10
# 1     1972-09-21
# 2     2008-07-23
# 3     1975-09-25
# 4     1994-10-28
# 5     2004-02-22
# 6     1994-03-11
# 7     1957-09-04
# 8     2010-09-24
# 9     1999-10-29
# 10    1994-10-06
# 11    2002-01-18
# 12    1966-12-23
# 14    1999-05-07
# 15    2003-01-16
# 16    1980-09-19
# 17    1990-09-20
# 18    1976-11-18
# 19    2014-11-06
# 20    1995-12-15
# 21    1991-03-05
# 22    1977-10-20
# 23    1998-10-30
# 24    2000-10-03
# 25    2003-05-09
# 26    2003-04-18
# 27    1997-12-20
# 28    2019-11-07
# 29    1948-03-11
# 30    1955-08-19
# 31    2000-05-19
# 32    2006-10-27
# 33    2006-12-22
# 34    1985-10-18
# 35    1999-08-27
# 36    1995-04-07
# 37    1991-12-19
# 38    1995-11-30
# 39    1994-11-25
# 40    2019-10-03
# 41    2012-02-24
# 42    2002-10-25
# 43    2015-02-12
# 44    1960-10-28
# 45    2046-11-21
# 46    1968-12-21
# 47    2015-10-11
# 48    1988-11-17
# 49    1937-03-12
# 50    2012-08-29
# 51    2013-01-17
# ...

# %%
df[df.release_year=='The 6th of marzo, year 1951']
# Out:
# Empty DataFrame
# Columns: [imbd title id, original_title, release_year, genre, duration, country, contemt_rating, director, unnamed: 8, income, votes, score]
# Index: []

# %%
df.loc[70, 'release_year']='10 August 1950'

# %%
df
# Out:
#     imbd title id                                     original_title  \
# 0       tt0111161                           The Shawshank Redemption
# 1       tt0068646                                      The Godfather
# 2       tt0468569                                    The Dark Knight
# 3       tt0071562                             The Godfather: Part II
# 4       tt0110912                                       Pulp Fiction
# 5       tt0167260      The Lord of the Rings: The Return of the King
# 6       tt0108052                                   Schindler's List
# 7       tt0050083                                       12 Angry Men
# 8       tt1375666                                          Inception
# 9       tt0137523                                         Fight Club
# 10      tt0109830                                       Forrest Gump
# 11      tt0120737  The Lord of the Rings: The Fellowship of the Ring
# 12      tt0060196                    Il buono, il brutto, il cattivo
# ...

# %%
df
# Out:
#     imbd title id                                     original_title  \
# 0       tt0111161                           The Shawshank Redemption
# 1       tt0068646                                      The Godfather
# 2       tt0468569                                    The Dark Knight
# 3       tt0071562                             The Godfather: Part II
# 4       tt0110912                                       Pulp Fiction
# 5       tt0167260      The Lord of the Rings: The Return of the King
# 6       tt0108052                                   Schindler's List
# 7       tt0050083                                       12 Angry Men
# 8       tt1375666                                          Inception
# 9       tt0137523                                         Fight Club
# 10      tt0109830                                       Forrest Gump
# 11      tt0120737  The Lord of the Rings: The Fellowship of the Ring
# 12      tt0060196                    Il buono, il brutto, il cattivo
# ...

# %%
df[df.release_year.isnull()]
# Out:
#    imbd title id original_title release_year         genre duration country  \
# 83     tt0086250       Scarface          NaT  Crime, Drama      170     USA
# 84     tt0075314    Taxi Driver          NaT  Crime, Drama      114     USA
#
#    contemt_rating         director  unnamed: 8      income    votes score
# 83              R   Brian De Palma         NaN  $ 66023585  721.343   7.8
# 84              R  Martin Scorsese         NaN  $ 28441292  703.264   7.7

# %%
df.loc[83, 'release_year']='9 December 1983'

# %%
df.loc[84, 'release_year']='8 February 1976'

# %%
df
# Out:
#     imbd title id                                     original_title  \
# 0       tt0111161                           The Shawshank Redemption
# 1       tt0068646                                      The Godfather
# 2       tt0468569                                    The Dark Knight
# 3       tt0071562                             The Godfather: Part II
# 4       tt0110912                                       Pulp Fiction
# 5       tt0167260      The Lord of the Rings: The Return of the King
# 6       tt0108052                                   Schindler's List
# 7       tt0050083                                       12 Angry Men
# 8       tt1375666                                          Inception
# 9       tt0137523                                         Fight Club
# 10      tt0109830                                       Forrest Gump
# 11      tt0120737  The Lord of the Rings: The Fellowship of the Ring
# 12      tt0060196                    Il buono, il brutto, il cattivo
# ...

# %%
df['votes'] = df['votes'].str.replace('.', '', regex=False)

# %%
df
# Out:
#     imbd title id                                     original_title  \
# 0       tt0111161                           The Shawshank Redemption
# 1       tt0068646                                      The Godfather
# 2       tt0468569                                    The Dark Knight
# 3       tt0071562                             The Godfather: Part II
# 4       tt0110912                                       Pulp Fiction
# 5       tt0167260      The Lord of the Rings: The Return of the King
# 6       tt0108052                                   Schindler's List
# 7       tt0050083                                       12 Angry Men
# 8       tt1375666                                          Inception
# 9       tt0137523                                         Fight Club
# 10      tt0109830                                       Forrest Gump
# 11      tt0120737  The Lord of the Rings: The Fellowship of the Ring
# 12      tt0060196                    Il buono, il brutto, il cattivo
# ...

# %%
df['votes'].astype('int')
# Out:
# 0      2278845
# 1      1572674
# 2      2241615
# 3      1098714
# 4      1780147
# 5      1604280
# 6      1183248
# 7       668473
# 8      2002816
# 9      1807440
# 10     1755490
# 11     1619920
# 12      672499
# 14     1632315
# 15     1449778
# 16     1132073
# 17      991505
# 18      891071
# 19     1449256
# 20     1402015
# 21     1234134
# 22     1204107
# 23     1203825
# 24     1112336
# 25      685856
# 26      626693
# 27      605648
# 28      470931
# 29      388310
# 30      307958
# 31     1308193
# 32     1159703
# 33     1155723
# 34     1027330
# 35     1014218
# 36     1007598
# 37      974970
# 38      968947
# 39      917248
# 40      855097
# 41      736691
# 42      707942
# 43      690732
# 44      586765
# 45      509953
# 46      295220
# 47      225438
# 48      223050
# 49      211250
# 50     1480582
# 51     1317856
# 52     1098879
# 53      974734
# 54      869480
# 55      865510
# 56      796486
# 57      768874
# 58      754786
# ...

# %%
df['score']=df['score'].replace(['9.','9,.0','8,9f','08.9','8..8','8:8','++8.7','8.7.','8,7e-0','8,6'], ['9','9.0','8.9','8.9','8.8','8.8','8.7','8.7','8.7','8.6'])

# %%
df.score=df.score.astype(float)

# %%
df[df['duration'].isnull()]
# Out:
#    imbd title id original_title release_year           genre duration country  \
# 14     tt0133093     The Matrix   1999-05-07  Action, Sci-Fi      NaN     USA
#
#    contemt_rating                         director  unnamed: 8       income  \
# 14              R  Lana Wachowski, Lilly Wachowski         NaN  $ 465718588
#
#       votes  score
# 14  1632315    8.7

# %%
df.loc[14, 'duration']=136

# %%
df.duration.info
# Out:
# <bound method Series.info of 0                 142
# 1                 175
# 2                 152
# 3                 220
# 4
# 5                 201
# 6                 Nan
# 7                  96
# 8                 148
# 9                 Inf
# 10                142
# 11               178c
# 12                161
# 14                136
# 15                179
# 16     Not Applicable
# 17                146
# 18                  -
# 19                169
# 20                127
# 21                118
# 22                121
# 23                169
# 24                189
# 25                130
# 26                125
# 27                116
# 28                132
# 29                130
# 30                207
# 31                155
# 32                151
# 33                130
# 34                116
# 35                119
# 36                110
# 37                137
# 38                106
# 39                 88
# 40                122
# 41                112
# ...

# %%
df[pd.to_numeric(df['duration'], errors='coerce').isna()]
# Out:
#    imbd title id                                     original_title  \
# 4      tt0110912                                       Pulp Fiction
# 6      tt0108052                                   Schindler's List
# 11     tt0120737  The Lord of the Rings: The Fellowship of the Ring
# 16     tt0080684     Star Wars: Episode V - The Empire Strikes Back
# 18     tt0073486                    One Flew Over the Cuckoo's Nest
#
#    release_year                       genre        duration      country  \
# 4    1994-10-28                Crime, Drama                          USA
# 6    1994-03-11   Biography, Drama, History             Nan          USA
# 11   2002-01-18    Action, Adventure, Drama            178c  New Zesland
# 16   1980-09-19  Action, Adventure, Fantasy  Not Applicable          USA
# 18   1976-11-18                       Drama               -          USA
#
#    contemt_rating           director  unnamed: 8       income    votes  score
# ...

# %%
df.loc[4, 'duration']=154

# %%
df.loc[6, 'duration']=195

# %%
df.loc[11, 'duration']=178

# %%
df.loc[16, 'duration']=124

# %%
df.loc[18, 'duration']=133

# %%
df['genre']=df['genre'].str.split(',', expand=True)[0]

# %%
df
# Out:
#     imbd title id                                     original_title  \
# 0       tt0111161                           The Shawshank Redemption
# 1       tt0068646                                      The Godfather
# 2       tt0468569                                    The Dark Knight
# 3       tt0071562                             The Godfather: Part II
# 4       tt0110912                                       Pulp Fiction
# 5       tt0167260      The Lord of the Rings: The Return of the King
# 6       tt0108052                                   Schindler's List
# 7       tt0050083                                       12 Angry Men
# 8       tt1375666                                          Inception
# 9       tt0137523                                         Fight Club
# 10      tt0109830                                       Forrest Gump
# 11      tt0120737  The Lord of the Rings: The Fellowship of the Ring
# 12      tt0060196                    Il buono, il brutto, il cattivo
# ...

# %%
df.drop(columns='imbd title id', inplace=True)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 100 entries, 0 to 100
# Data columns (total 12 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   imbd title id   100 non-null    object
#  1   original_title  100 non-null    object
#  2   release_year    100 non-null    datetime64[ns]
#  3   genre           100 non-null    object
#  4   duration        100 non-null    object
#  5   country         100 non-null    object
#  6   contemt_rating  77 non-null     object
#  7   director        100 non-null    object
#  8   unnamed: 8      0 non-null      float64
#  9   income          100 non-null    object
#  10  votes           100 non-null    object
#  11  score           100 non-null    float64
# dtypes: datetime64[ns](1), float64(2), object(9)
# memory usage: 14.2+ KB

# %%
df
# Out:
#     imbd title id                                     original_title  \
# 0       tt0111161                           The Shawshank Redemption
# 1       tt0068646                                      The Godfather
# 2       tt0468569                                    The Dark Knight
# 3       tt0071562                             The Godfather: Part II
# 4       tt0110912                                       Pulp Fiction
# 5       tt0167260      The Lord of the Rings: The Return of the King
# 6       tt0108052                                   Schindler's List
# 7       tt0050083                                       12 Angry Men
# 8       tt1375666                                          Inception
# 9       tt0137523                                         Fight Club
# 10      tt0109830                                       Forrest Gump
# 11      tt0120737  The Lord of the Rings: The Fellowship of the Ring
# 12      tt0060196                    Il buono, il brutto, il cattivo
# ...

# %%
df
# Out:
#     imbd title id                                     original_title  \
# 0       tt0111161                           The Shawshank Redemption
# 1       tt0068646                                      The Godfather
# 2       tt0468569                                    The Dark Knight
# 3       tt0071562                             The Godfather: Part II
# 4       tt0110912                                       Pulp Fiction
# 5       tt0167260      The Lord of the Rings: The Return of the King
# 6       tt0108052                                   Schindler's List
# 7       tt0050083                                       12 Angry Men
# 8       tt1375666                                          Inception
# 9       tt0137523                                         Fight Club
# 10      tt0109830                                       Forrest Gump
# 11      tt0120737  The Lord of the Rings: The Fellowship of the Ring
# 12      tt0060196                    Il buono, il brutto, il cattivo
# ...

# %%
df
# Out:
#                                         original_title release_year  \
# 0                             The Shawshank Redemption   1995-02-10
# 1                                        The Godfather   1972-09-21
# 2                                      The Dark Knight   2008-07-23
# 3                               The Godfather: Part II   1975-09-25
# 4                                         Pulp Fiction   1994-10-28
# 5        The Lord of the Rings: The Return of the King   2004-02-22
# 6                                     Schindler's List   1994-03-11
# 7                                         12 Angry Men   1957-09-04
# 8                                            Inception   2010-09-24
# 9                                           Fight Club   1999-10-29
# 10                                        Forrest Gump   1994-10-06
# 11   The Lord of the Rings: The Fellowship of the Ring   2002-01-18
# 12                     Il buono, il brutto, il cattivo   1966-12-23
# ...

# %%
df.country=df['country'].replace(['New Zesland','New Zeland'], 'New Zealand')

# %%
df['contemt_rating']=df['contemt_rating'].replace({'PG-13':'PG'})

# %%
df[df.contemt_rating.isnull()]
# Out:
#                         original_title release_year      genre duration  \
# 27                    La vita B9 bella   1997-12-20     Comedy      116
# 28                        Gisaengchung   2019-11-07     Comedy      132
# 36                               LÃ©on   1995-04-07     Action      110
# 40                               Joker   2019-10-03      Crime      122
# 41                        Intouchables   2012-02-24  Biography      112
# 47                      Hotaru no haka   2015-10-11  Animation       89
# 48               Nuovo Cinema Paradiso   1988-11-17      Drama      155
# 56              Avengers: Infinity War   2018-04-25     Action      149
# 58                   Avengers: Endgame   2019-04-24     Action      181
# 62                         Rear Window   1955-04-14    Mystery      112
# 63                                Coco   2017-12-28  Animation      105
# 65   Spider-Man: Into the Spider-Verse   2018-12-25  Animation      117
# ...

# %%
df.country=df['country'].replace('Italy1', 'Italy')

# %%
df.country.value_counts()
# Out:
# country
# USA             64
# UK              12
# Italy            5
# Japan            4
# New Zealand      3
# France           3
# South Korea      2
# Germany          2
# Brazil           1
# India            1
# Denmark          1
# West Germany     1
# Iran             1
# Name: count, dtype: int64

# %%
df
# Out:
#                                         original_title release_year  \
# 0                             The Shawshank Redemption   1995-02-10
# 1                                        The Godfather   1972-09-21
# 2                                      The Dark Knight   2008-07-23
# 3                               The Godfather: Part II   1975-09-25
# 4                                         Pulp Fiction   1994-10-28
# 5        The Lord of the Rings: The Return of the King   2004-02-22
# 6                                     Schindler's List   1994-03-11
# 7                                         12 Angry Men   1957-09-04
# 8                                            Inception   2010-09-24
# 9                                           Fight Club   1999-10-29
# 10                                        Forrest Gump   1994-10-06
# 11   The Lord of the Rings: The Fellowship of the Ring   2002-01-18
# 12                     Il buono, il brutto, il cattivo   1966-12-23
# ...

# %%
df.income=df.income.str[2:]

# %%
df
# Out:
#                                         original_title release_year  \
# 0                             The Shawshank Redemption   1995-02-10
# 1                                        The Godfather   1972-09-21
# 2                                      The Dark Knight   2008-07-23
# 3                               The Godfather: Part II   1975-09-25
# 4                                         Pulp Fiction   1994-10-28
# 5        The Lord of the Rings: The Return of the King   2004-02-22
# 6                                     Schindler's List   1994-03-11
# 7                                         12 Angry Men   1957-09-04
# 8                                            Inception   2010-09-24
# 9                                           Fight Club   1999-10-29
# 10                                        Forrest Gump   1994-10-06
# 11   The Lord of the Rings: The Fellowship of the Ring   2002-01-18
# 12                     Il buono, il brutto, il cattivo   1966-12-23
# ...

# %%
df.loc[3, 'income']=408035783

# %%
df
# Out:
#                                         original_title release_year  \
# 0                             The Shawshank Redemption   1995-02-10
# 1                                        The Godfather   1972-09-21
# 2                                      The Dark Knight   2008-07-23
# 3                               The Godfather: Part II   1975-09-25
# 4                                         Pulp Fiction   1994-10-28
# 5        The Lord of the Rings: The Return of the King   2004-02-22
# 6                                     Schindler's List   1994-03-11
# 7                                         12 Angry Men   1957-09-04
# 8                                            Inception   2010-09-24
# 9                                           Fight Club   1999-10-29
# 10                                        Forrest Gump   1994-10-06
# 11   The Lord of the Rings: The Fellowship of the Ring   2002-01-18
# 12                     Il buono, il brutto, il cattivo   1966-12-23
# ...

# %%
df.describe()
# Out:
#               release_year       score
# count                  100  100.000000
# mean   1991-06-19 19:55:12    8.240000
# min    1937-03-12 00:00:00    7.400000
# 25%    1979-04-24 06:00:00    7.900000
# 50%    1995-11-30 12:00:00    8.300000
# 75%    2005-09-17 18:00:00    8.600000
# max    2046-11-21 00:00:00    9.300000
# std                    NaN    0.451485

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 100 entries, 0 to 100
# Data columns (total 9 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   original_title  100 non-null    object
#  1   release_year    100 non-null    datetime64[ns]
#  2   genre           100 non-null    object
#  3   duration        100 non-null    object
#  4   country         100 non-null    object
#  5   director        100 non-null    object
#  6   income          100 non-null    object
#  7   votes           100 non-null    int32
#  8   score           100 non-null    float64
# dtypes: datetime64[ns](1), float64(1), int32(1), object(6)
# memory usage: 11.5+ KB

# %%
df.votes=df.votes.astype(int)

# %%
df['income'] = pd.to_numeric(df['income'], errors='coerce', downcast='integer')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 100 entries, 0 to 100
# Data columns (total 9 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   original_title  100 non-null    object
#  1   release_year    100 non-null    datetime64[ns]
#  2   genre           100 non-null    object
#  3   duration        100 non-null    object
#  4   country         100 non-null    object
#  5   director        100 non-null    object
#  6   income          100 non-null    int64
#  7   votes           100 non-null    int32
#  8   score           100 non-null    float64
# dtypes: datetime64[ns](1), float64(1), int32(1), int64(1), object(5)
# memory usage: 11.5+ KB

# %%
df.income.sum()
# Out:
# 29912549111

# %%
df.describe()
# Out:
#               release_year    duration        income         votes       score
# count                  100  100.000000  1.000000e+02  1.000000e+02  100.000000
# mean   1991-06-19 19:55:12  136.040000  2.991255e+08  8.297713e+05    8.240000
# min    1937-03-12 00:00:00   81.000000  5.760000e+02  1.957890e+05    7.400000
# 25%    1979-04-24 06:00:00  115.000000  2.374174e+07  3.890690e+05    7.900000
# 50%    1995-11-30 12:00:00  130.000000  1.093370e+08  7.515385e+05    8.300000
# 75%    2005-09-17 18:00:00  152.250000  4.052080e+08  1.102243e+06    8.600000
# max    2046-11-21 00:00:00  229.000000  2.797801e+09  2.278845e+06    9.300000
# std                    NaN   31.026518  4.360335e+08  4.829340e+05    0.451485

# %%
df.loc[9, 'duration']=139

# %%
df.duration=df.duration.astype(int)
